# %% [markdown]
# Steam Scraping data Save to CSV file

# %%
import requests
from bs4 import BeautifulSoup
import csv
import re
import time

# Daftar filter pencarian yang akan digunakan
search_filters = ['topsellers', 'mostplayed', 'newreleases', 'upcomingreleases']

# Jumlah maksimum data yang ingin kita scrap
MAX_DATA = 10000
line_count = 0

# Membuka file CSV untuk menyimpan hasil scraping
with open('steam_games.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Name', 'Published Date', 'Original Price', 'Discount Price', 'Reviews', 'Search Query'])

    for search_filter in search_filters:
        page = 1

        while line_count < MAX_DATA:
            # URL pencarian berdasarkan kategori dan halaman
            url = f'https://store.steampowered.com/search/?filter={search_filter}&page={page}'

            # Mengirim request ke Steam
            response = requests.get(url, headers={"User-Agent": "Mozilla/5.0"})
            if response.status_code != 200:
                print(f"Gagal mengakses halaman {url}")
                break  # Hentikan jika gagal mengambil data

            # Parse konten HTML
            doc = BeautifulSoup(response.content, 'html.parser')

            # Mencari semua game di halaman tersebut
            games = doc.find_all('div', {'class': 'responsive_search_name_combined'})

            if not games:
                print(f"Tidak ada game ditemukan di halaman {page} untuk filter {search_filter}")
                break  # Hentikan jika tidak ada game di halaman ini

            for game in games:
                if line_count >= MAX_DATA:
                    break  # Berhenti jika sudah mencapai batas data

                try:
                    name = game.find('span', {'class': 'title'}).text.strip()
                except AttributeError:
                    name = "N/A"

                try:
                    published_date = game.find('div', {'class': 'col search_released responsive_secondrow'}).text.strip()
                except AttributeError:
                    published_date = "N/A"

                try:
                    original_price_elem = game.find('div', {'class': 'discount_original_price'})
                    original_price = original_price_elem.text.strip() if original_price_elem else 'N/A'
                except AttributeError:
                    original_price = "N/A"

                try:
                    discount_price_elem = game.find('div', {'class': 'discount_final_price'})
                    discount_price = discount_price_elem.text.strip() if discount_price_elem else 'N/A'
                except AttributeError:
                    discount_price = "N/A"

                try:
                    review_summary = game.find('span', {'class': 'search_review_summary'})
                    reviews_html = review_summary['data-tooltip-html'] if review_summary else 'N/A'
                    match = re.search(r'(\d+,*\d*)\s+user reviews', reviews_html)
                    reviews_number = match.group(1).replace(',', '') if match else 'N/A'
                except AttributeError:
                    reviews_number = "N/A"

                # Menulis hasil scraping ke dalam file CSV
                writer.writerow([name, published_date, original_price, discount_price, reviews_number, search_filter])
                line_count += 1

            print(f"✔ Scraped {line_count} data so far...")
            page += 1  # Pindah ke halaman berikutnya
            time.sleep(2)  # Delay agar tidak terkena rate limit

print(f"✅ Scraping selesai! Total data tersimpan: {line_count}")
# Out:
# ✔ Scraped 25 data so far...
# ✔ Scraped 50 data so far...
# ✔ Scraped 75 data so far...
# ✔ Scraped 100 data so far...
# ✔ Scraped 125 data so far...
# ✔ Scraped 150 data so far...
# ✔ Scraped 175 data so far...
# ✔ Scraped 200 data so far...
# ✔ Scraped 225 data so far...
# ✔ Scraped 250 data so far...
# ✔ Scraped 275 data so far...
# ✔ Scraped 300 data so far...
# ✔ Scraped 325 data so far...
# ✔ Scraped 350 data so far...
# ✔ Scraped 375 data so far...
# ✔ Scraped 400 data so far...
# ✔ Scraped 425 data so far...
# ✔ Scraped 450 data so far...
# ✔ Scraped 475 data so far...
# ✔ Scraped 500 data so far...
# ✔ Scraped 525 data so far...
# ✔ Scraped 550 data so far...
# ✔ Scraped 575 data so far...
# ✔ Scraped 600 data so far...
# ✔ Scraped 625 data so far...
# ✔ Scraped 650 data so far...
# ✔ Scraped 675 data so far...
# ✔ Scraped 700 data so far...
# ✔ Scraped 725 data so far...
# ✔ Scraped 750 data so far...
# ✔ Scraped 775 data so far...
# ✔ Scraped 800 data so far...
# ✔ Scraped 825 data so far...
# ✔ Scraped 850 data so far...
# ✔ Scraped 875 data so far...
# ✔ Scraped 900 data so far...
# ✔ Scraped 925 data so far...
# ✔ Scraped 950 data so far...
# ✔ Scraped 975 data so far...
# ✔ Scraped 1000 data so far...
# ✔ Scraped 1025 data so far...
# ✔ Scraped 1050 data so far...
# ✔ Scraped 1075 data so far...
# ✔ Scraped 1100 data so far...
# ✔ Scraped 1125 data so far...
# ✔ Scraped 1150 data so far...
# ✔ Scraped 1175 data so far...
# ✔ Scraped 1200 data so far...
# ✔ Scraped 1225 data so far...
# ✔ Scraped 1250 data so far...
# ✔ Scraped 1275 data so far...
# ✔ Scraped 1300 data so far...
# ✔ Scraped 1325 data so far...
# ✔ Scraped 1350 data so far...
# ✔ Scraped 1375 data so far...
# ✔ Scraped 1400 data so far...
# ✔ Scraped 1425 data so far...
# ✔ Scraped 1450 data so far...
# ✔ Scraped 1475 data so far...
# ✔ Scraped 1500 data so far...
# ✔ Scraped 1525 data so far...
# ✔ Scraped 1550 data so far...
# ✔ Scraped 1575 data so far...
# ✔ Scraped 1600 data so far...
# ✔ Scraped 1625 data so far...
# ✔ Scraped 1650 data so far...
# ✔ Scraped 1675 data so far...
# ✔ Scraped 1700 data so far...
# ✔ Scraped 1725 data so far...
# ✔ Scraped 1750 data so far...
# ✔ Scraped 1775 data so far...
# ✔ Scraped 1800 data so far...
# ✔ Scraped 1825 data so far...
# ✔ Scraped 1850 data so far...
# ✔ Scraped 1875 data so far...
# ✔ Scraped 1900 data so far...
# ✔ Scraped 1925 data so far...
# ✔ Scraped 1950 data so far...
# ✔ Scraped 1975 data so far...
# ✔ Scraped 2000 data so far...
# ✔ Scraped 2025 data so far...
# ✔ Scraped 2050 data so far...
# ✔ Scraped 2075 data so far...
# ✔ Scraped 2100 data so far...
# ✔ Scraped 2125 data so far...
# ✔ Scraped 2150 data so far...
# ✔ Scraped 2175 data so far...
# ✔ Scraped 2200 data so far...
# ✔ Scraped 2225 data so far...
# ✔ Scraped 2250 data so far...
# ✔ Scraped 2275 data so far...
# ✔ Scraped 2300 data so far...
# ✔ Scraped 2325 data so far...
# ✔ Scraped 2350 data so far...
# ✔ Scraped 2375 data so far...
# ✔ Scraped 2400 data so far...
# ✔ Scraped 2425 data so far...
# ✔ Scraped 2450 data so far...
# ✔ Scraped 2475 data so far...
# ✔ Scraped 2500 data so far...
# ✔ Scraped 2525 data so far...
# ✔ Scraped 2550 data so far...
# ✔ Scraped 2575 data so far...
# ✔ Scraped 2600 data so far...
# ✔ Scraped 2625 data so far...
# ✔ Scraped 2650 data so far...
# ✔ Scraped 2675 data so far...
# ✔ Scraped 2700 data so far...
# ✔ Scraped 2725 data so far...
# ✔ Scraped 2750 data so far...
# ✔ Scraped 2775 data so far...
# ✔ Scraped 2800 data so far...
# ✔ Scraped 2825 data so far...
# ✔ Scraped 2850 data so far...
# ✔ Scraped 2875 data so far...
# ✔ Scraped 2900 data so far...
# ✔ Scraped 2925 data so far...
# ✔ Scraped 2950 data so far...
# ✔ Scraped 2975 data so far...
# ✔ Scraped 3000 data so far...
# ✔ Scraped 3025 data so far...
# ✔ Scraped 3050 data so far...
# ✔ Scraped 3075 data so far...
# ✔ Scraped 3100 data so far...
# ✔ Scraped 3125 data so far...
# ✔ Scraped 3150 data so far...
# ✔ Scraped 3175 data so far...
# ✔ Scraped 3200 data so far...
# ✔ Scraped 3225 data so far...
# ✔ Scraped 3250 data so far...
# ✔ Scraped 3275 data so far...
# ✔ Scraped 3300 data so far...
# ✔ Scraped 3325 data so far...
# ✔ Scraped 3350 data so far...
# ✔ Scraped 3375 data so far...
# ✔ Scraped 3400 data so far...
# ✔ Scraped 3425 data so far...
# ✔ Scraped 3450 data so far...
# ✔ Scraped 3475 data so far...
# ✔ Scraped 3500 data so far...
# ✔ Scraped 3525 data so far...
# ✔ Scraped 3550 data so far...
# ✔ Scraped 3575 data so far...
# ✔ Scraped 3600 data so far...
# ✔ Scraped 3625 data so far...
# ✔ Scraped 3650 data so far...
# ✔ Scraped 3675 data so far...
# ✔ Scraped 3700 data so far...
# ✔ Scraped 3725 data so far...
# ✔ Scraped 3750 data so far...
# ✔ Scraped 3775 data so far...
# ✔ Scraped 3800 data so far...
# ✔ Scraped 3825 data so far...
# ✔ Scraped 3850 data so far...
# ✔ Scraped 3875 data so far...
# ✔ Scraped 3900 data so far...
# ✔ Scraped 3925 data so far...
# ✔ Scraped 3950 data so far...
# ✔ Scraped 3975 data so far...
# ✔ Scraped 4000 data so far...
# ✔ Scraped 4025 data so far...
# ✔ Scraped 4050 data so far...
# ✔ Scraped 4075 data so far...
# ✔ Scraped 4100 data so far...
# ✔ Scraped 4125 data so far...
# ✔ Scraped 4150 data so far...
# ✔ Scraped 4175 data so far...
# ✔ Scraped 4200 data so far...
# ✔ Scraped 4225 data so far...
# ✔ Scraped 4250 data so far...
# ✔ Scraped 4275 data so far...
# ✔ Scraped 4300 data so far...
# ✔ Scraped 4325 data so far...
# ✔ Scraped 4350 data so far...
# ✔ Scraped 4375 data so far...
# ✔ Scraped 4400 data so far...
# ✔ Scraped 4425 data so far...
# ✔ Scraped 4450 data so far...
# ✔ Scraped 4475 data so far...
# ✔ Scraped 4500 data so far...
# ✔ Scraped 4525 data so far...
# ✔ Scraped 4550 data so far...
# ✔ Scraped 4575 data so far...
# ✔ Scraped 4600 data so far...
# ✔ Scraped 4625 data so far...
# ✔ Scraped 4650 data so far...
# ✔ Scraped 4675 data so far...
# ✔ Scraped 4700 data so far...
# ✔ Scraped 4725 data so far...
# ✔ Scraped 4750 data so far...
# ✔ Scraped 4775 data so far...
# ✔ Scraped 4800 data so far...
# ✔ Scraped 4825 data so far...
# ✔ Scraped 4850 data so far...
# ✔ Scraped 4875 data so far...
# ✔ Scraped 4900 data so far...
# ✔ Scraped 4925 data so far...
# ✔ Scraped 4950 data so far...
# ✔ Scraped 4975 data so far...
# ✔ Scraped 5000 data so far...
# ✔ Scraped 5025 data so far...
# ✔ Scraped 5050 data so far...
# ✔ Scraped 5075 data so far...
# ✔ Scraped 5100 data so far...
# ✔ Scraped 5125 data so far...
# ✔ Scraped 5150 data so far...
# ✔ Scraped 5175 data so far...
# ✔ Scraped 5200 data so far...
# ✔ Scraped 5225 data so far...
# ✔ Scraped 5250 data so far...
# ✔ Scraped 5275 data so far...
# ✔ Scraped 5300 data so far...
# ✔ Scraped 5325 data so far...
# ✔ Scraped 5350 data so far...
# ✔ Scraped 5375 data so far...
# ✔ Scraped 5400 data so far...
# ✔ Scraped 5425 data so far...
# ✔ Scraped 5450 data so far...
# ✔ Scraped 5475 data so far...
# ✔ Scraped 5500 data so far...
# ✔ Scraped 5525 data so far...
# ✔ Scraped 5550 data so far...
# ✔ Scraped 5575 data so far...
# ✔ Scraped 5600 data so far...
# ✔ Scraped 5625 data so far...
# ✔ Scraped 5650 data so far...
# ✔ Scraped 5675 data so far...
# ✔ Scraped 5700 data so far...
# ✔ Scraped 5725 data so far...
# ✔ Scraped 5750 data so far...
# ✔ Scraped 5775 data so far...
# ✔ Scraped 5800 data so far...
# ✔ Scraped 5825 data so far...
# ✔ Scraped 5850 data so far...
# ✔ Scraped 5875 data so far...
# ✔ Scraped 5900 data so far...
# ✔ Scraped 5925 data so far...
# ✔ Scraped 5950 data so far...
# ✔ Scraped 5975 data so far...
# ✔ Scraped 6000 data so far...
# ✔ Scraped 6025 data so far...
# ✔ Scraped 6050 data so far...
# ✔ Scraped 6075 data so far...
# ✔ Scraped 6100 data so far...
# ✔ Scraped 6125 data so far...
# ✔ Scraped 6150 data so far...
# ✔ Scraped 6175 data so far...
# ✔ Scraped 6200 data so far...
# ✔ Scraped 6225 data so far...
# ✔ Scraped 6250 data so far...
# ✔ Scraped 6275 data so far...
# ✔ Scraped 6300 data so far...
# ✔ Scraped 6325 data so far...
# ✔ Scraped 6350 data so far...
# ✔ Scraped 6375 data so far...
# ✔ Scraped 6400 data so far...
# ✔ Scraped 6425 data so far...
# ✔ Scraped 6450 data so far...
# ✔ Scraped 6475 data so far...
# ✔ Scraped 6500 data so far...
# ✔ Scraped 6525 data so far...
# ✔ Scraped 6550 data so far...
# ✔ Scraped 6575 data so far...
# ✔ Scraped 6600 data so far...
# ✔ Scraped 6625 data so far...
# ✔ Scraped 6650 data so far...
# ✔ Scraped 6675 data so far...
# ✔ Scraped 6700 data so far...
# ✔ Scraped 6725 data so far...
# ✔ Scraped 6750 data so far...
# ✔ Scraped 6775 data so far...
# ✔ Scraped 6800 data so far...
# ✔ Scraped 6825 data so far...
# ✔ Scraped 6850 data so far...
# ✔ Scraped 6875 data so far...
# ✔ Scraped 6900 data so far...
# ✔ Scraped 6925 data so far...
# ✔ Scraped 6950 data so far...
# ✔ Scraped 6975 data so far...
# ✔ Scraped 7000 data so far...
# ✔ Scraped 7025 data so far...
# ✔ Scraped 7050 data so far...
# ✔ Scraped 7075 data so far...
# ✔ Scraped 7100 data so far...
# ✔ Scraped 7125 data so far...
# ✔ Scraped 7150 data so far...
# ✔ Scraped 7175 data so far...
# ✔ Scraped 7200 data so far...
# ✔ Scraped 7225 data so far...
# ✔ Scraped 7250 data so far...
# ✔ Scraped 7275 data so far...
# ✔ Scraped 7300 data so far...
# ✔ Scraped 7325 data so far...
# ✔ Scraped 7350 data so far...
# ✔ Scraped 7375 data so far...
# ✔ Scraped 7400 data so far...
# ✔ Scraped 7425 data so far...
# ✔ Scraped 7450 data so far...
# ✔ Scraped 7475 data so far...
# ✔ Scraped 7500 data so far...
# ✔ Scraped 7525 data so far...
# ✔ Scraped 7550 data so far...
# ✔ Scraped 7575 data so far...
# ✔ Scraped 7600 data so far...
# ✔ Scraped 7625 data so far...
# ✔ Scraped 7650 data so far...
# ✔ Scraped 7675 data so far...
# ✔ Scraped 7700 data so far...
# ✔ Scraped 7725 data so far...
# ✔ Scraped 7750 data so far...
# ✔ Scraped 7775 data so far...
# ✔ Scraped 7800 data so far...
# ✔ Scraped 7825 data so far...
# ✔ Scraped 7850 data so far...
# ✔ Scraped 7875 data so far...
# ✔ Scraped 7900 data so far...
# ✔ Scraped 7925 data so far...
# ✔ Scraped 7950 data so far...
# ✔ Scraped 7975 data so far...
# ✔ Scraped 8000 data so far...
# ✔ Scraped 8025 data so far...
# ✔ Scraped 8050 data so far...
# ✔ Scraped 8075 data so far...
# ✔ Scraped 8100 data so far...
# ✔ Scraped 8125 data so far...
# ✔ Scraped 8150 data so far...
# ✔ Scraped 8175 data so far...
# ✔ Scraped 8200 data so far...
# ✔ Scraped 8225 data so far...
# ✔ Scraped 8250 data so far...
# ✔ Scraped 8275 data so far...
# ✔ Scraped 8300 data so far...
# ✔ Scraped 8325 data so far...
# ✔ Scraped 8350 data so far...
# ✔ Scraped 8375 data so far...
# ✔ Scraped 8400 data so far...
# ✔ Scraped 8425 data so far...
# ✔ Scraped 8450 data so far...
# ✔ Scraped 8475 data so far...
# ✔ Scraped 8500 data so far...
# ✔ Scraped 8525 data so far...
# ✔ Scraped 8550 data so far...
# ✔ Scraped 8575 data so far...
# ✔ Scraped 8600 data so far...
# ✔ Scraped 8625 data so far...
# ✔ Scraped 8650 data so far...
# ✔ Scraped 8675 data so far...
# ✔ Scraped 8700 data so far...
# ✔ Scraped 8725 data so far...
# ✔ Scraped 8750 data so far...
# ✔ Scraped 8775 data so far...
# ✔ Scraped 8800 data so far...
# ✔ Scraped 8825 data so far...
# ✔ Scraped 8850 data so far...
# ✔ Scraped 8875 data so far...
# ✔ Scraped 8900 data so far...
# ✔ Scraped 8925 data so far...
# ✔ Scraped 8950 data so far...
# ✔ Scraped 8975 data so far...
# ✔ Scraped 9000 data so far...
# ✔ Scraped 9025 data so far...
# ✔ Scraped 9050 data so far...
# ✔ Scraped 9075 data so far...
# ✔ Scraped 9100 data so far...
# ✔ Scraped 9125 data so far...
# ✔ Scraped 9139 data so far...
# Tidak ada game ditemukan di halaman 367 untuk filter topsellers
# ✔ Scraped 9164 data so far...
# ✔ Scraped 9189 data so far...
# ✔ Scraped 9214 data so far...
# ✔ Scraped 9239 data so far...
# ✔ Scraped 9264 data so far...
# ✔ Scraped 9289 data so far...
# ✔ Scraped 9314 data so far...
# ✔ Scraped 9339 data so far...
# ✔ Scraped 9364 data so far...
# ✔ Scraped 9389 data so far...
# ✔ Scraped 9414 data so far...
# ✔ Scraped 9439 data so far...
# ✔ Scraped 9464 data so far...
# ✔ Scraped 9489 data so far...
# ✔ Scraped 9514 data so far...
# ✔ Scraped 9539 data so far...
# ✔ Scraped 9564 data so far...
# ✔ Scraped 9589 data so far...
# ✔ Scraped 9614 data so far...
# ✔ Scraped 9639 data so far...
# ✔ Scraped 9664 data so far...
# ✔ Scraped 9689 data so far...
# ✔ Scraped 9714 data so far...
# ✔ Scraped 9739 data so far...
# ✔ Scraped 9764 data so far...
# ✔ Scraped 9789 data so far...
# ✔ Scraped 9814 data so far...
# ✔ Scraped 9839 data so far...
# ✔ Scraped 9864 data so far...
# ✔ Scraped 9889 data so far...
# ✔ Scraped 9914 data so far...
# ✔ Scraped 9939 data so far...
# ✔ Scraped 9964 data so far...
# ✔ Scraped 9989 data so far...
# ✔ Scraped 10000 data so far...
# ✅ Scraping selesai! Total data tersimpan: 10000
